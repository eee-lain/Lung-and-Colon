# %% [markdown]
# # Lung and Colon Cancer Detection Test

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ## Loading model

# %%
model = tf.keras.models.load_model('trained_lung_coloncnn.keras')

# %% [markdown]
# ## Input Image

# %%
image_path = r'C:\Users\elain\coding\Notebook\Lung and colon disease\lung and colon\colon_n\colonn124.jpeg'

# %%
img = cv2.imread(image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# ## Image Processing

# %%
image = tf.keras.preprocessing.image.load_img(image_path, target_size=(128, 128))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])
print(input_arr)
# Out:
# [[[[189. 156. 209.]
#    [208. 178. 228.]
#    [226. 196. 248.]
#    ...
#    [154. 102. 210.]
#    [148.  96. 196.]
#    [142.  91. 184.]]
#
#   [[152. 121. 201.]
#    [150. 108. 216.]
#    [210. 169. 247.]
#    ...
#    [161. 110. 213.]
#    [173. 108. 210.]
#    [224. 152. 226.]]
#
#   [[138. 110. 187.]
#    [130.  84. 209.]
#    [184. 141. 213.]
#    ...
#    [228. 162. 252.]
#    [182. 107. 208.]
#    [228. 155. 228.]]
#
#   ...
#
#   [[214. 158. 231.]
#    [216. 178. 229.]
#    [221. 183. 234.]
#    ...
#    [225. 216. 243.]
#    [227. 153. 238.]
#    [220. 173. 227.]]
#
#   [[221. 175. 240.]
#    [220. 192. 230.]
#    [235. 208. 243.]
#    ...
#    [193. 169. 231.]
#    [219. 161. 235.]
#    [209. 163. 225.]]
#
#   [[223. 188. 244.]
#    [227. 212. 235.]
#    [232. 215. 233.]
#    ...
#    [183. 128. 221.]
#    [239. 190. 237.]
#    [218. 160. 219.]]]]

# %% [markdown]
# ### Class labels

# %%
cls = {
    'Colon adenocarcinoma': 0,
    'Colon Normal': 1,
    'Lung adenocarcinoma': 2,
    'Lung Normal': 3,
    'Lung squamous cell carcinoma': 4,
    
}
cls_list = list(cls.items())

# %% [markdown]
# ## Predict Image

# %%
predictions = model.predict(input_arr)
result_index = np.argmax(predictions)
print(result_index)
model_prediction = cls_list[result_index][0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 4

# %%
plt.imshow(img)
plt.title(f"Disease Name: {model_prediction}")
plt.xticks([])
plt.yticks([])
plt.show()

# %%
colon_n\colonn8.jpeg
colon_aca\colonca890.jpeg
lung_n\lungn1.jpeg
